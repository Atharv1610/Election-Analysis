# %%
import requests
from bs4 import BeautifulSoup
import pandas as pds

# %%
import os
import pandas as pd

def load_election_data(base_folder):
    state_data = {}
    for state_folder in os.listdir(base_folder):
        state_path = os.path.join(base_folder, state_folder)
        if os.path.isdir(state_path):
            state_data[state_folder] = {}
            for party_folder in os.listdir(state_path):
                party_path = os.path.join(state_path, party_folder)
                if os.path.isdir(party_path):
                    for file in os.listdir(party_path):
                        if file.endswith('.csv'):
                            csv_path = os.path.join(party_path, file)
                            # Load CSV data into DataFrame
                            df = pd.read_csv(csv_path)
                            state_data[state_folder][party_folder] = df
    return state_data

def calculate_dominance(state_data):
    dominance_results = {}
    
    for state, parties in state_data.items():
        dominance_results[state] = {}
        total_constituencies = 0
        
        for party, df in parties.items():
            total_constituencies += len(df)
        for party, df in parties.items():
            constituencies_won = len(df)
            dominance_percentage = (constituencies_won / total_constituencies) * 100
            dominance_results[state][party] = dominance_percentage
            
    return dominance_results

# %%
base_folder = 'state'
state_data = load_election_data(base_folder)
dominance_results = calculate_dominance(state_data)

print("Dominance Results:")
for state, parties in dominance_results.items():
    print(f"{state}:")
    for party, dominance in parties.items():
        print(f"  {party}: {dominance:.2f}%")
# Out:
# Dominance Results:
# Andaman & Nicobar Islands:
#   Bharatiya Janata Party - BJP: 100.00%
# Andhra Pradesh:
#   Bharatiya Janata Party - BJP: 12.00%
#   Janasena Party - JnP: 8.00%
#   Telugu Desam - TDP: 64.00%
#   Yuvajana Sramika Rythu Congress Party - YSRCP: 16.00%
# Arunachal Pradesh:
#   Bharatiya Janata Party - BJP: 100.00%
# Assam:
#   Asom Gana Parishad - AGP: 7.14%
#   Bharatiya Janata Party - BJP: 64.29%
#   Indian National Congress - INC: 21.43%
#   United People’s Party, Liberal - UPPL: 7.14%
# Bihar:
#   Bharatiya Janata Party - BJP: 30.00%
#   Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L): 5.00%
#   Hindustani Awam Morcha (Secular) - HAMS: 2.50%
#   Independent - IND: 2.50%
#   Indian National Congress - INC: 7.50%
#   Janata Dal  (United) - JD(U): 30.00%
#   Lok Janshakti Party(Ram Vilas) - LJPRV: 12.50%
#   Rashtriya Janata Dal - RJD: 10.00%
# Chandigarh:
#   Indian National Congress - INC: 100.00%
# Chhattisgarh:
#   Bharatiya Janata Party - BJP: 90.91%
#   Indian National Congress - INC: 9.09%
# Dadra & Nagar Haveli and Daman & Diu:
#   Bharatiya Janata Party - BJP: 50.00%
#   Independent - IND: 50.00%
# Goa:
#   Bharatiya Janata Party - BJP: 50.00%
#   Indian National Congress - INC: 50.00%
# Gujarat:
#   Bharatiya Janata Party - BJP: 96.15%
#   Indian National Congress - INC: 3.85%
# Haryana:
#   Bharatiya Janata Party - BJP: 50.00%
#   Indian National Congress - INC: 50.00%
# Himachal Pradesh:
#   Bharatiya Janata Party - BJP: 100.00%
# Jammu and Kashmir:
#   Bharatiya Janata Party - BJP: 40.00%
#   Independent - IND: 20.00%
#   Jammu & Kashmir National Conference - JKN: 40.00%
# Jharkhand:
#   AJSU Party - AJSUP: 7.14%
#   Bharatiya Janata Party - BJP: 57.14%
#   Indian National Congress - INC: 14.29%
#   Jharkhand Mukti Morcha - JMM: 21.43%
# Karnataka:
#   Bharatiya Janata Party - BJP: 60.71%
#   Indian National Congress - INC: 32.14%
#   Janata Dal  (Secular) - JD(S): 7.14%
# Kerala:
#   Bharatiya Janata Party - BJP: 5.00%
#   Communist Party of India  (Marxist) - CPI(M): 5.00%
#   Indian National Congress - INC: 70.00%
#   Indian Union Muslim League - IUML: 10.00%
#   Kerala Congress - KEC: 5.00%
#   Revolutionary Socialist Party - RSP: 5.00%
# Ladakh:
#   Independent - IND: 100.00%
# Lakshadweep:
#   Indian National Congress - INC: 100.00%
# Madhya Pradesh:
#   Bharatiya Janata Party - BJP: 100.00%
# Maharashtra:
#   Bharatiya Janata Party - BJP: 18.75%
#   Independent - IND: 2.08%
#   Indian National Congress - INC: 27.08%
#   Nationalist Congress Party - NCP: 2.08%
#   Nationalist Congress Party – Sharadchandra Pawar - NCPSP: 16.67%
#   Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT: 18.75%
#   Shiv Sena - SHS: 14.58%
# Manipur:
#   Indian National Congress - INC: 100.00%
# Meghalaya:
#   Indian National Congress - INC: 50.00%
#   Voice of the People Party - VOTPP: 50.00%
# Mizoram:
#   Zoram People’s Movement - ZPM: 100.00%
# Nagaland:
#   Indian National Congress - INC: 100.00%
# NCT OF Delhi:
#   Bharatiya Janata Party - BJP: 100.00%
# Odisha:
#   Bharatiya Janata Party - BJP: 95.24%
#   Indian National Congress - INC: 4.76%
# Puducherry:
#   Indian National Congress - INC: 100.00%
# Punjab:
#   Aam Aadmi Party - AAAP: 23.08%
#   Independent - IND: 15.38%
#   Indian National Congress - INC: 53.85%
#   Shiromani Akali Dal - SAD: 7.69%
# Rajasthan:
#   Bharat Adivasi Party - BHRTADVSIP: 4.00%
#   Bharatiya Janata Party - BJP: 56.00%
#   Communist Party of India  (Marxist) - CPI(M): 4.00%
#   Indian National Congress - INC: 32.00%
#   Rashtriya Loktantrik Party - RLTP: 4.00%
# Sikkim:
#   Sikkim Krantikari Morcha - SKM: 100.00%
# Tamil Nadu:
#   Communist Party of India  (Marxist) - CPI(M): 5.13%
#   Communist Party of India - CPI: 5.13%
#   Dravida Munnetra Kazhagam - DMK: 56.41%
#   Indian National Congress - INC: 23.08%
#   Indian Union Muslim League - IUML: 2.56%
#   Marumalarchi Dravida Munnetra Kazhagam - MDMK: 2.56%
#   Viduthalai Chiruthaigal Katchi - VCK: 5.13%
# Telangana:
#   All India Majlis-E-Ittehadul Muslimeen - AIMIM: 5.88%
#   Bharatiya Janata Party - BJP: 47.06%
#   Indian National Congress - INC: 47.06%
# Tripura:
#   Bharatiya Janata Party - BJP: 100.00%
# Uttar Pradesh:
#   Aazad Samaj Party (Kanshi Ram) - ASPKR: 1.25%
#   Apna Dal (Soneylal) - ADAL: 1.25%
#   Bharatiya Janata Party - BJP: 41.25%
#   Indian National Congress - INC: 7.50%
#   Rashtriya Lok Dal - RLD: 2.50%
#   Samajwadi Party - SP: 46.25%
# Uttarakhand:
#   Bharatiya Janata Party - BJP: 100.00%
# West Bengal:
#   All India Trinamool Congress - AITC: 69.05%
#   Bharatiya Janata Party - BJP: 28.57%
#   Indian National Congress - INC: 2.38%

# %% [markdown]
# Average Margin of Victory

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
base_folder = 'state'

def load_election_data(base_folder):
    state_data = {}
    for state_folder in os.listdir(base_folder):
        state_path = os.path.join(base_folder, state_folder)
        if os.path.isdir(state_path):
            state_data[state_folder] = {}
            for party_folder in os.listdir(state_path):
                party_path = os.path.join(state_path, party_folder)
                if os.path.isdir(party_path):
                    for file in os.listdir(party_path):
                        if file.endswith('.csv'):
                            csv_path = os.path.join(party_path, file)
                            df = pd.read_csv(csv_path)
                            df['Total Votes'] = pd.to_numeric(df['Total Votes'], errors='coerce')
                            df['Margin'] = pd.to_numeric(df['Margin'], errors='coerce')
                            state_data[state_folder][party_folder] = df
    return state_data

def calculate_average_margin(state_data):
    average_margin = {}
    
    for state, parties in state_data.items():
        for party, df in parties.items():
            if party not in average_margin:
                average_margin[party] = []
            average_margin[party].extend(df['Margin'].dropna().tolist())
    
    average_margin = {party: sum(margins)/len(margins) if margins else 0 for party, margins in average_margin.items()}
    
    return average_margin

def calculate_total_seats(state_data):
    total_seats = {}
    
    for state, parties in state_data.items():
        for party, df in parties.items():
            if party not in total_seats:
                total_seats[party] = 0
            total_seats[party] += len(df)
    
    return total_seats

state_data = load_election_data(base_folder)
average_margin = calculate_average_margin(state_data)
total_seats = calculate_total_seats(state_data)

print("Average Margin of Victory for Each Party:")
for party, margin in average_margin.items():
    print(f"{party}: {margin:.2f}")

plt.figure(figsize=(12, 8))
plt.bar(average_margin.keys(), average_margin.values(), color='skyblue')
plt.xlabel('Parties')
plt.ylabel('Average Margin of Victory')
plt.title('Average Margin of Victory for Each Party')
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

required_majority = 272
party_closest_to_majority = max(total_seats, key=lambda party: min(total_seats[party], required_majority))
margin_to_majority = required_majority - total_seats[party_closest_to_majority]
# Out:
# Average Margin of Victory for Each Party:
# Bharatiya Janata Party - BJP: 192809.77
# Janasena Party - JnP: 226335.00
# Telugu Desam - TDP: 228807.94
# Yuvajana Sramika Rythu Congress Party - YSRCP: 50978.75
# Asom Gana Parishad - AGP: 222351.00
# Indian National Congress - INC: 131372.95
# United People’s Party, Liberal - UPPL: 51583.00
# Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L): 82833.00
# Hindustani Awam Morcha (Secular) - HAMS: 101812.00
# Independent - IND: 89900.29
# Janata Dal  (United) - JD(U): 115534.42
# Lok Janshakti Party(Ram Vilas) - LJPRV: 144120.60
# Rashtriya Janata Dal - RJD: 84241.75
# Jammu & Kashmir National Conference - JKN: 235105.00
# AJSU Party - AJSUP: 80880.00
# Jharkhand Mukti Morcha - JMM: 123064.33
# Janata Dal  (Secular) - JD(S): 178004.00
# Communist Party of India  (Marxist) - CPI(M): 186559.25
# Indian Union Muslim League - IUML: 234220.00
# Kerala Congress - KEC: 87266.00
# Revolutionary Socialist Party - RSP: 150302.00
# Nationalist Congress Party - NCP: 82784.00
# Nationalist Congress Party – Sharadchandra Pawar - NCPSP: 89571.38
# Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT: 112825.56
# Shiv Sena - SHS: 100053.29
# Voice of the People Party - VOTPP: 371910.00
# Zoram People’s Movement - ZPM: 68288.00
# Aam Aadmi Party - AAAP: 75839.00
# Shiromani Akali Dal - SAD: 49656.00
# Bharat Adivasi Party - BHRTADVSIP: 247054.00
# Rashtriya Loktantrik Party - RLTP: 42225.00
# Sikkim Krantikari Morcha - SKM: 80830.00
# Communist Party of India - CPI: 167442.50
# Dravida Munnetra Kazhagam - DMK: 230981.00
# Marumalarchi Dravida Munnetra Kazhagam - MDMK: 313094.00
# Viduthalai Chiruthaigal Katchi - VCK: 87128.50
# All India Majlis-E-Ittehadul Muslimeen - AIMIM: 338087.00
# Aazad Samaj Party (Kanshi Ram) - ASPKR: 151473.00
# Apna Dal (Soneylal) - ADAL: 37810.00
# Rashtriya Lok Dal - RLD: 98483.50
# Samajwadi Party - SP: 77555.84
# All India Trinamool Congress - AITC: 169343.55

# %% [markdown]
# Party Closest to Majority

# %%
print(f"\nParty closest to majority: {party_closest_to_majority} with {total_seats[party_closest_to_majority]} seats")
print(f"Margin to majority: {margin_to_majority} seats")
# Out:
# Party closest to majority: Bharatiya Janata Party - BJP with 240 seats
# Margin to majority: 32 seats

# %% [markdown]
# Candidate with Margin of Victory < 100000

# %%
import os
import pandas as pd

base_folder = 'state'

def load_election_data(base_folder):
    state_data = {}
    for state_folder in os.listdir(base_folder):
        state_path = os.path.join(base_folder, state_folder)
        if os.path.isdir(state_path):
            state_data[state_folder] = {}
            for party_folder in os.listdir(state_path):
                party_path = os.path.join(state_path, party_folder)
                if os.path.isdir(party_path):
                    for file in os.listdir(party_path):
                        if file.endswith('.csv'):
                            csv_path = os.path.join(party_path, file)
                            df = pd.read_csv(csv_path)
                            df['Total Votes'] = pd.to_numeric(df['Total Votes'], errors='coerce')
                            df['Margin'] = pd.to_numeric(df['Margin'], errors='coerce')
                            state_data[state_folder][party_folder] = df
    return state_data

def find_close_contests(state_data, margin_threshold=10000):
    close_contests = []
    
    for state, parties in state_data.items():
        for party, df in parties.items():
            for _, row in df.iterrows():
                if row['Margin'] < margin_threshold:
                    close_contests.append({
                        'State': state,
                        'Party': party,
                        'Parliament Constituency': row['Parliament Constituency'],
                        'Winning Candidate': row['Winning Candidate'],
                        'Total Votes': row['Total Votes'],
                        'Margin': row['Margin']
                    })
    
    return close_contests

state_data = load_election_data(base_folder)
close_contests = find_close_contests(state_data)

print("Close Contests (Margin of Victory < 10,000 Votes):")
for contest in close_contests:
    print(f"State: {contest['State']}, Party: {contest['Party']}, "
          f"Parliament Constituency: {contest['Parliament Constituency']}, "
          f"Winning Candidate: {contest['Winning Candidate']}, "
          f"Total Votes: {contest['Total Votes']}, Margin: {contest['Margin']}")
# Out:
# Close Contests (Margin of Victory < 10,000 Votes):
# State: Chandigarh, Party: Indian National Congress - INC, Parliament Constituency: Chandigarh(1), Winning Candidate: MANISH TEWARI, Total Votes: 216657, Margin: 2504
# State: Chhattisgarh, Party: Bharatiya Janata Party - BJP, Parliament Constituency: KANKER(11), Winning Candidate: BHOJRAJ NAG, Total Votes: 597624, Margin: 1884
# State: Dadra & Nagar Haveli and Daman & Diu, Party: Independent - IND, Parliament Constituency: Daman & Diu (1), Winning Candidate: PATEL UMESHBHAI BABUBHAI, Total Votes: 42523, Margin: 6225
# State: Kerala, Party: Indian National Congress - INC, Parliament Constituency: Attingal(19), Winning Candidate: ADV ADOOR PRAKASH, Total Votes: 328051, Margin: 684
# State: Lakshadweep, Party: Indian National Congress - INC, Parliament Constituency: Lakshadweep(1), Winning Candidate: MUHAMMED HAMDULLAH SAYEED, Total Votes: 25726, Margin: 2647
# State: Maharashtra, Party: Indian National Congress - INC, Parliament Constituency: Dhule(2), Winning Candidate: BACHHAV SHOBHA DINESH, Total Votes: 583866, Margin: 3831
# State: Maharashtra, Party: Nationalist Congress Party – Sharadchandra Pawar - NCPSP, Parliament Constituency: Beed(39), Winning Candidate: BAJRANG MANOHAR SONWANE, Total Votes: 683950, Margin: 6553
# State: Maharashtra, Party: Shiv Sena - SHS, Parliament Constituency: Mumbai North West(27), Winning Candidate: RAVINDRA DATTARAM WAIKAR, Total Votes: 452644, Margin: 48
# State: Odisha, Party: Bharatiya Janata Party - BJP, Parliament Constituency: Jajpur(8), Winning Candidate: RABINDRA NARAYAN BEHERA, Total Votes: 534239, Margin: 1587
# State: Punjab, Party: Indian National Congress - INC, Parliament Constituency: Firozpur(10), Winning Candidate: SHER SINGH GHUBAYA, Total Votes: 266626, Margin: 3242
# State: Rajasthan, Party: Bharatiya Janata Party - BJP, Parliament Constituency: JAIPUR RURAL(6), Winning Candidate: RAO RAJENDRA SINGH, Total Votes: 617877, Margin: 1615
# State: Tamil Nadu, Party: Indian National Congress - INC, Parliament Constituency: VIRUDHUNAGAR(34), Winning Candidate: MANICKAM TAGORE B, Total Votes: 385256, Margin: 4379
# State: Telangana, Party: Bharatiya Janata Party - BJP, Parliament Constituency: Mahbubnagar(11), Winning Candidate: ARUNA. D. K, Total Votes: 510747, Margin: 4500
# State: Uttar Pradesh, Party: Bharatiya Janata Party - BJP, Parliament Constituency: Farrukhabad(40), Winning Candidate: MUKESH RAJPUT, Total Votes: 487963, Margin: 2678
# State: Uttar Pradesh, Party: Bharatiya Janata Party - BJP, Parliament Constituency: Phulpur(51), Winning Candidate: PRAVEEN PATEL, Total Votes: 452600, Margin: 4332
# State: Uttar Pradesh, Party: Bharatiya Janata Party - BJP, Parliament Constituency: Bansgaon(67), Winning Candidate: KAMLESH PASWAN, Total Votes: 428693, Margin: 3150
# State: Uttar Pradesh, Party: Samajwadi Party - SP, Parliament Constituency: Dhaurahra(29), Winning Candidate: ANAND BHADAURIYA, Total Votes: 443743, Margin: 4449
# State: Uttar Pradesh, Party: Samajwadi Party - SP, Parliament Constituency: Hamirpur(47), Winning Candidate: AJENDRA SINGH LODHI, Total Votes: 490683, Margin: 2629
# State: Uttar Pradesh, Party: Samajwadi Party - SP, Parliament Constituency: Salempur(71), Winning Candidate: RAMASHANKAR RAJBHAR, Total Votes: 405472, Margin: 3573
# State: West Bengal, Party: All India Trinamool Congress - AITC, Parliament Constituency: Arambagh(29), Winning Candidate: BAG MITALI, Total Votes: 712587, Margin: 6399
# State: West Bengal, Party: Bharatiya Janata Party - BJP, Parliament Constituency: Bishnupur(37), Winning Candidate: KHAN SAUMITRA, Total Votes: 680130, Margin: 5567

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Base folder containing state-wise data
base_folder = 'state'

# Function to load party-wise election results from CSV files
def load_election_data(base_folder):
    state_data = {}
    for state_folder in os.listdir(base_folder):
        state_path = os.path.join(base_folder, state_folder)
        if os.path.isdir(state_path):
            state_data[state_folder] = {}
            for party_folder in os.listdir(state_path):
                party_path = os.path.join(state_path, party_folder)
                if os.path.isdir(party_path):
                    for file in os.listdir(party_path):
                        if file.endswith('.csv'):
                            csv_path = os.path.join(party_path, file)
                            # Load CSV data into DataFrame
                            df = pd.read_csv(csv_path)
                            # Convert 'Total Votes' and 'Margin' columns to numeric, coercing errors to NaN
                            df['Total Votes'] = pd.to_numeric(df['Total Votes'], errors='coerce')
                            df['Margin'] = pd.to_numeric(df['Margin'], errors='coerce')
                            state_data[state_folder][party_folder] = df
    return state_data

# Function to extract margins of victory from the loaded data
def extract_margins_of_victory(state_data):
    margins = []
    for state, parties in state_data.items():
        for party, df in parties.items():
            margins.extend(df['Margin'].dropna().tolist())
    return margins

# Load election data from folders
state_data = load_election_data(base_folder)

# Extract margins of victory from the loaded data
margins_of_victory = extract_margins_of_victory(state_data)

# Plot histogram of margins of victory
plt.figure(figsize=(10, 6))
plt.hist(margins_of_victory, bins=20, edgecolor='black')
plt.title('Distribution of Margins of Victory Across Constituencies')
plt.xlabel('Margin of Victory')
plt.ylabel('Number of Constituencies')
plt.grid(True)
plt.tight_layout()
plt.show()
